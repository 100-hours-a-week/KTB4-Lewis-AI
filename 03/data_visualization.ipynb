# %% [markdown]
# # 데이터 시각화: 모든 미니퀘스트 수행

# %% [markdown]
# ## 정형 데이터 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# 샘플 데이터프레임을 생성한 후, 데이터의 기본 정보를 출력하는 코드를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# data = {
#     '이름': ['김철수', '이영희', '박민수', '최지현', '홍길동'],
#     '나이': [25, 30, 35, 28, 40],
#     '직업': ['개발자', '마케터', '개발자', '디자이너', 'CEO'],
#     '연봉': [4000, 3500, 5000, 4200, 10000],
#     '가입일': ['2020-05-21', '2019-07-15', '2021-01-10', '2018-11-03', '2017-09-27']
# }
# ```
#
# </aside>

# %%
import pandas as pd

data = {
    '이름': ['김철수', '이영희', '박민수', '최지현', '홍길동'],
    '나이': [25, 30, 35, 28, 40],
    '직업': ['개발자', '마케터', '개발자', '디자이너', 'CEO'],
    '연봉': [4000, 3500, 5000, 4200, 10000],
    '가입일': ['2020-05-21', '2019-07-15', '2021-01-10', '2018-11-03', '2017-09-27']
    }

df = pd.DataFrame(data)

print(df.info())
print("\n", df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      5 non-null      object
#  1   나이      5 non-null      int64
#  2   직업      5 non-null      object
#  3   연봉      5 non-null      int64
#  4   가입일     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 332.0+ bytes
# None
#
#               나이           연봉
# count   5.00000      5.00000
# mean   31.60000   5340.00000
# std     5.94138   2660.45109
# min    25.00000   3500.00000
# 25%    28.00000   4000.00000
# 50%    30.00000   4200.00000
# 75%    35.00000   5000.00000
# max    40.00000  10000.00000

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉샘플 데이터에서 나이가 30 이상이고 연봉이 5000 이하인 사람들만 필터링하는 코드를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# data = {
#     '이름': ['김철수', '이영희', '박민수', '최지현', '홍길동', '정지훈', '이지은'],
#     '나이': [25, 30, 35, 28, 40, 50, 22],
#     '직업': ['개발자', '마케터', '개발자', '디자이너', 'CEO', '디자이너', '마케터'],
#     '연봉': [4000, 3500, 5000, 4200, 10000, 4600, 3300],
#     '가입일': ['2020-05-21', '2019-07-15', '2021-01-10', '2018-11-03', '2017-09-27', '2016-04-11', '2022-03-19']
# }
# ```
#
# </aside>

# %%
import pandas as pd

data = {
    '이름': ['김철수', '이영희', '박민수', '최지현', '홍길동', '정지훈', '이지은'],
    '나이': [25, 30, 35, 28, 40, 50, 22],
    '직업': ['개발자', '마케터', '개발자', '디자이너', 'CEO', '디자이너', '마케터'],
    '연봉': [4000, 3500, 5000, 4200, 10000, 4600, 3300],
    '가입일': ['2020-05-21', '2019-07-15', '2021-01-10', '2018-11-03', '2017-09-27', '2016-04-11', '2022-03-19']
}

df = pd.DataFrame(data)

df_filtered = df[(df['나이'] >= 30) & (df['연봉'] <= 5000)].copy()

print(df_filtered)
# Out:
#     이름  나이    직업    연봉         가입일
# 1  이영희  30   마케터  3500  2019-07-15
# 2  박민수  35   개발자  5000  2021-01-10
# 5  정지훈  50  디자이너  4600  2016-04-11

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 샘플 데이터에서 가입 연도가 2019년 이전인 사람들을 찾아 연봉을 10% 인상한 후, 전체 평균 연봉을 계산하는 코드를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# data = {
#     '이름': ['김철수', '이영희', '박민수', '최지현', '홍길동', '정지훈', '이지은'],
#     '나이': [25, 30, 35, 28, 40, 50, 22],
#     '직업': ['개발자', '마케터', '개발자', '디자이너', 'CEO', '디자이너', '마케터'],
#     '연봉': [4000, 3500, 5000, 4200, 10000, 4600, 3300],
#     '가입일': ['2020-05-21', '2019-07-15', '2021-01-10', '2018-11-03', '2017-09-27', '2016-04-11', '2022-03-19']
# }
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    '이름': ['김철수', '이영희', '박민수', '최지현', '홍길동', '정지훈', '이지은'],
    '연봉': [4000, 3500, 5000, 4200, 10000, 4600, 3300],
    '가입일': pd.to_datetime(['2020-05-21', '2019-07-15', '2021-01-10', '2018-11-03', '2017-09-27', '2016-04-11', '2022-03-19'])
})

df['수정연봉'] = np.where(df['가입일'].dt.year < 2019, df['연봉'] * 1.1, df['연봉'])

print(df)
print(f"인상전 전체 평균 연봉: {df['연봉'].mean():.2f}")
print(f"전체 평균 연봉: {df['수정연봉'].mean():.2f}")
# Out:
#     이름     연봉        가입일     수정연봉
# 0  김철수   4000 2020-05-21   4000.0
# 1  이영희   3500 2019-07-15   3500.0
# 2  박민수   5000 2021-01-10   5000.0
# 3  최지현   4200 2018-11-03   4620.0
# 4  홍길동  10000 2017-09-27  11000.0
# 5  정지훈   4600 2016-04-11   5060.0
# 6  이지은   3300 2022-03-19   3300.0
# 인상전 전체 평균 연봉: 4942.86
# 전체 평균 연봉: 5211.43

# %% [markdown]
# ## 비정형 데이터 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# JSON 형식의 데이터를 직접 생성한 후, Pandas 데이터프레임으로 변환하는 코드를 작성하세요.
#
# ```python
# # JSON 데이터 직접 생성
# data = '''
# [
#     {"이름": "김철수", "나이": 25, "직업": "개발자", "연봉": 4000},
#     {"이름": "이영희", "나이": 30, "직업": "마케터", "연봉": 3500},
#     {"이름": "박민수", "나이": 35, "직업": "디자이너", "연봉": 4200}
# ]
# '''
# ```
#
# </aside>

# %%
import json
import pandas as pd

data = '''
[
    {"이름": "김철수", "나이": 25, "직업": "개발자", "연봉": 4000},
    {"이름": "이영희", "나이": 30, "직업": "마케터", "연봉": 3500},
    {"이름": "박민수", "나이": 35, "직업": "디자이너", "연봉": 4200}
]
'''

parsed_data = json.loads(data)

df = pd.DataFrame(parsed_data)

print(df)
# Out:
#     이름  나이    직업    연봉
# 0  김철수  25   개발자  4000
# 1  이영희  30   마케터  3500
# 2  박민수  35  디자이너  4200

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 아래 샘플 데이터에서 한글과 공백을 제외한 모든 문자를 **제거하고, 공백을 하나로 정리하는 코드**를 작성하세요.
#
# ```python
# # 샘플 데이터 (비정형 텍스트)
# text = "안녕하세요!!! 저는 AI 모델-입니다. 12345 데이터를   정리해 보겠습니다."
# ```
#
# </aside>

# %%
import re


text = "안녕하세요!!! 저는 AI 모델-입니다. 12345 데이터를   정리해 보겠습니다."

cleaned_text = re.sub(r'[^가-힣\s]', '', text)

final_text = re.sub(r'\s+', ' ', cleaned_text).strip()

print(f"원본: {text}")
print(f"정제: {final_text}")
# Out:
# 원본: 안녕하세요!!! 저는 AI 모델-입니다. 12345 데이터를   정리해 보겠습니다.
# 정제: 안녕하세요 저는 모델입니다 데이터를 정리해 보겠습니다

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# **주어진 텍스트 데이터를 문장 단위로 분리한 후, 각 문장의 단어 개수를 데이터프레임으로 변환하는 코드**를 작성하세요.
#
# ```python
# # 샘플 텍스트 데이터
# text = "자연어 처리는 재미있다. 파이썬과 pandas를 활용하면 편리하다. 데이터 분석은 흥미롭다."
# ```
#
# </aside>

# %%
import pandas as pd


text = "자연어 처리는 재미있다. 파이썬과 pandas를 활용하면 편리하다. 데이터 분석은 흥미롭다."

sentences = [s.strip() for s in text.split('.') if s.strip()]

word_counts = [len(s.split()) for s in sentences]

df_sentences = pd.DataFrame({'문장': sentences,'단어개수': word_counts})

print(df_sentences)
# Out:
#                        문장  단어개수
# 0            자연어 처리는 재미있다     3
# 1  파이썬과 pandas를 활용하면 편리하다     4
# 2            데이터 분석은 흥미롭다     3

# %% [markdown]
# ## 막대 그래프 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# **matplotlib**을 활용하여 **5개의 카테고리**와 각각의 값이 포함된 **기본 세로 막대 그래프**를 생성하는 코드를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# categories = ['A', 'B', 'C', 'D', 'E']
# values = [12, 25, 18, 30, 22]
# ```
#
# </aside>

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D', 'E']
values = [12, 25, 18, 30, 22]

plt.bar(categories, values)

plt.title('Bar Chart')
plt.xlabel('Categories')
plt.ylabel('Values')

# 그래프 표시
plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **누적형 막대 그래프**를 생성하여, 두 개의 연도별 데이터를 **각각 다른 색상으로 누적하여 표현**하는 코드를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# categories = ['A', 'B', 'C', 'D', 'E']
# values_2023 = [10, 15, 20, 25, 30]
# values_2024 = [5, 10, 12, 18, 22]
# ```
#
# </aside>

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D', 'E']
values_2023 = [10, 15, 20, 25, 30]
values_2024 = [5, 10, 12, 18, 22]

plt.bar(categories, values_2023, label='2023')
plt.bar(categories, values_2024, bottom=values_2023, label='2024')  # bottom 지정이 핵심

plt.title('Stacked Bar Chart (2023 vs 2024)')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.legend()

# 그래프 표시
plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 한 기업의 **부서별 연간 성과(2023년 vs 2024년)를 비교하는 그룹형 막대 그래프**를 생성하는 코드를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# departments = ['Sales', 'Marketing', 'IT', 'HR', 'Finance']
# performance_2023 = [80, 70, 90, 60, 75]
# performance_2024 = [85, 75, 95, 65, 80]
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

departments = ['Sales', 'Marketing', 'IT', 'HR', 'Finance']
performance_2023 = [80, 70, 90, 60, 75]
performance_2024 = [85, 75, 95, 65, 80]

x = np.arange(len(departments))

plt.bar(x - 0.2, performance_2023, width=0.4)
plt.bar(x + 0.2, performance_2024, width=0.4)

plt.xticks(x, departments)
plt.show()

# %% [markdown]
# ## 히스토그램 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# 정규 분포를 따르는 **1000개의 데이터**를 생성한 후, **구간을 15개로 설정한 히스토그램을 그리는 코드**를 작성하세요.
#
# ```python
# # 정규 분포를 따르는 1000개의 데이터 생성
# data = np.random.randn(1000)
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(1000)

plt.hist(data, bins=15)
plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 두 개의 서로 다른 정규 분포를 따르는 데이터셋을 생성한 후, **두 히스토그램을 같은 그래프에서 겹쳐서 비교하는 코드**를 작성하세요.
#
# ```python
# # 첫 번째 데이터셋 (평균 0, 표준편차 1)
# data1 = np.random.randn(1000)
#
# # 두 번째 데이터셋 (평균 3, 표준편차 1)
# data2 = np.random.randn(1000) + 3
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.randn(1000)

data2 = np.random.randn(1000) + 3

plt.hist(data1, alpha=0.5)
plt.hist(data2, alpha=0.5)

plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 한 데이터셋의 **누적 히스토그램**을 그린 후, X축과 Y축의 적절한 레이블을 설정하는 코드를 작성하세요.
#
# ```python
# # 정규 분포를 따르는 1000개의 데이터 생성
# data = np.random.randn(1000)
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(1000)

plt.hist(data, cumulative=True)
plt.xlabel('Value')
plt.ylabel('Cumulative Frequency')

plt.show()

# %% [markdown]
# ## 산점도 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# 두 개의 리스트 `x = [1, 2, 3, 4, 5]`, `y = [3, 1, 4, 5, 2]`를 사용하여 **산점도를 그리고, X축과 Y축의 라벨을 추가하는 코드**를 작성하세요.
#
# ```python
# # 데이터 생성
# x = [1, 2, 3, 4, 5]
# y = [3, 1, 4, 5, 2]
# ```
#
# </aside>

# %%
import matplotlib.pyplot as plt

# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [3, 1, 4, 5, 2]

plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# `numpy`를 활용하여 **난수를 생성한 후, 산점도를 그리고 점의 색상과 투명도를 설정하는 코드**를 작성하세요.
#
# ```python
# # 난수 데이터 생성
# np.random.seed(42)
# x = np.random.rand(50) * 10  # 0~10 범위의 난수 50개
# y = np.random.rand(50) * 10  # 0~10 범위의 난수 50개
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 난수 데이터 생성
np.random.seed(42)
x = np.random.rand(50) * 10  # 0~10 범위의 난수 50개
y = np.random.rand(50) * 10  # 0~10 범위의 난수 50개

plt.scatter(x, y, c='red', alpha=0.5)

plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# `numpy`를 활용하여 **세 개의 그룹('A', 'B', 'C')에 속하는 데이터의 산점도를 서로 다른 색상으로 그리는 코드**를 작성하세요.
#
# ```python
# # 데이터 생성
# np.random.seed(10)
# x = np.random.randn(50) * 2
# y = np.random.randn(50) * 2
# categories = np.random.choice(['A', 'B', 'C'], size=50)
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
np.random.seed(10)
x = np.random.randn(50) * 2
y = np.random.randn(50) * 2
categories = np.random.choice(['A', 'B', 'C'], size=50)

x = np.array(x)
y = np.array(y)

for cat, color in zip(['A', 'B', 'C'], ['red', 'blue', 'green']):
    mask = (categories == cat)
    plt.scatter(x[mask], y[mask], c=color)

plt.show()

# %% [markdown]
# ## 박스플롯 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# 평균 0, 표준편차 1을 따르는 **정규분포 난수 50개를 생성한 후**, 해당 데이터를 이용해 **기본 박스 플롯을 출력하는 코드**를 작성하세요.
#
# ```python
# # 정규분포를 따르는 난수 50개 생성
# np.random.seed(42)
# data = np.random.randn(50)
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 정규분포를 따르는 난수 50개 생성
np.random.seed(42)
data = np.random.randn(50)

plt.boxplot(data)
plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **세 개의 그룹(Group A, Group B, Group C)** 에 대해 **각각 다른 평균을 가지는 데이터**를 생성하고, 이를 이용해 **다중 박스 플롯을 그리는 코드**를 작성하세요.
#
# ```python
# # 랜덤 데이터 생성 (각 그룹별 평균 다르게 설정)
# np.random.seed(42)
# group_a = np.random.randn(50) * 1.5  # 표준편차 1.5, 평균 0
# group_b = np.random.randn(50) * 1.5 + 3  # 표준편차 1.5, 평균 3
# group_c = np.random.randn(50) * 1.5 - 3  # 표준편차 1.5, 평균 -3
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 랜덤 데이터 생성 (각 그룹별 평균 다르게 설정)
np.random.seed(42)
group_a = np.random.randn(50) * 1.5  # 표준편차 1.5, 평균 0
group_b = np.random.randn(50) * 1.5 + 3  # 표준편차 1.5, 평균 3
group_c = np.random.randn(50) * 1.5 - 3  # 표준편차 1.5, 평균 -3

plt.boxplot([group_a, group_b, group_c], tick_labels=['group A', 'group B', 'group C'])
plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 평균이 **서로 다른 두 개의 그룹(Group X, Group Y)** 을 비교하는 박스 플롯을 그리세요.
#
# 단, **이상값을 강조하고, 스타일을 커스터마이징**해야 합니다.
#
# ```python
# # 랜덤 데이터 생성 (두 그룹의 평균 다르게 설정)
# np.random.seed(42)
# group_x = np.random.randn(50) * 2  # 표준편차 2, 평균 0
# group_y = np.random.randn(50) * 2 + 5  # 표준편차 2, 평균 5
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 랜덤 데이터 생성 (두 그룹의 평균 다르게 설정)
np.random.seed(42)
group_x = np.random.randn(50) * 2  # 표준편차 2, 평균 0
group_y = np.random.randn(50) * 2 + 5  # 표준편차 2, 평균 5

outlier_style = dict(marker='o', markerfacecolor='red', markersize=8, linestyle='none')

plt.boxplot([group_x, group_y], tick_labels=['Group X', 'Group Y'], flierprops=outlier_style)

plt.show()

# %% [markdown]
# ## 고급 다중 그래프 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# `plt.subplots()`를 사용하여 **2x1 형태의 서브플롯을 만들고**, 첫 번째 서브플롯에는 `y = x^2`, 두 번째 서브플롯에는 `y = x^3`을 그리는 코드를 작성하세요.
#
# ```python
# # 데이터 생성
# x = np.linspace(-5, 5, 100)
# y1 = x ** 2  # x의 제곱
# y2 = x ** 3  # x의 세제곱
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
x = np.linspace(-5, 5, 100)
y1 = x ** 2  # x의 제곱
y2 = x ** 3  # x의 세제곱

fig, axes = plt.subplots(2, 1)

axes[0].plot(x, y1)

axes[1].plot(x, y2)

plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **X축을 공유하는 1행 2열 형태의 서브플롯을 생성하고**, 첫 번째 서브플롯에는 **정규 분포를 따르는 난수의 히스토그램**, 두 번째 서브플롯에는 **균등 분포를 따르는 난수의 히스토그램**을 그리세요.
#
# ```python
# # 데이터 생성
# normal_data = np.random.randn(1000)  # 정규 분포 난수 1000개
# uniform_data = np.random.rand(1000)  # 균등 분포 난수 1000개
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
normal_data = np.random.randn(1000)  # 정규 분포 난수 1000개
uniform_data = np.random.rand(1000)  # 균등 분포 난수 1000개

fig, axes = plt.subplots(1, 2, sharex=True)

axes[0].hist(normal_data)

axes[1].hist(uniform_data)

plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# `gridspec`을 사용하여 **불규칙한 레이아웃의 서브플롯을 생성하고**, 각각 **선 그래프, 산점도, 막대 그래프, 히스토그램**을 그리세요.
#
# ```python
# # 데이터 생성
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.random.randn(100)
# categories = ['A', 'B', 'C', 'D', 'E']
# values = [3, 7, 5, 2, 8]
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# 데이터 생성
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.random.randn(100)
categories = ['A', 'B', 'C', 'D', 'E']
values = [3, 7, 5, 2, 8]

fig = plt.figure()
gs = gridspec.GridSpec(2, 3)

# 1. 선 그래프 
ax1 = fig.add_subplot(gs[0, :])
ax1.plot(x, y1)

# 2. 산점도
ax2 = fig.add_subplot(gs[1, 0])
ax2.scatter(x, y2)

# 3. 막대 그래프 
ax3 = fig.add_subplot(gs[1, 1])
ax3.bar(categories, values)

# 4. 히스토그램 
ax4 = fig.add_subplot(gs[1, 2])
ax4.hist(y2)

plt.show()

# %% [markdown]
# ## 벤 다이어그램 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# **두 개의 과일 집합을 정의하고, 두 집합의 차집합(한 집합에만 존재하는 요소)을 출력하는 코드**를 작성하세요.
#
# ```python
# # 두 개의 과일 집합 정의
# set_A = {"사과", "바나나", "체리", "망고"}
# set_B = {"바나나", "망고", "포도", "수박"}
# ```
#
# </aside>

# %%
# 두 개의 과일 집합 정의
set_A = {"사과", "바나나", "체리", "망고"}
set_B = {"바나나", "망고", "포도", "수박"}

result = set_A.difference(set_B)

print(result)
# Out:
# {'체리', '사과'}

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **벤 다이어그램을 그리지 않고, 세 개의 집합을 비교하여 각 집합이 단독으로 가지는 요소 개수와 교집합 개수를 계산하는 코드**를 작성하세요.
#
# ```python
# # 세 개의 과일 집합 정의
# set_A = {"사과", "바나나", "체리", "망고"}
# set_B = {"바나나", "망고", "포도", "수박"}
# set_C = {"망고", "수박", "딸기", "오렌지"}
# ```
#
# </aside>

# %%
# 세 개의 과일 집합 정의
set_A = {"사과", "바나나", "체리", "망고"}
set_B = {"바나나", "망고", "포도", "수박"}
set_C = {"망고", "수박", "딸기", "오렌지"}

only_A = set_A - (set_B | set_C)
only_B = set_B - (set_A | set_C)
only_C = set_C - (set_A | set_B)

intersection_all = set_A & set_B & set_C

print(f"A 단독 요소 개수: {len(only_A)}")
print(f"B 단독 요소 개수: {len(only_B)}")
print(f"C 단독 요소 개수: {len(only_C)}")
print(f"세 집합의 교집합 개수: {len(intersection_all)}")
# Out:
# A 단독 요소 개수: 2
# B 단독 요소 개수: 1
# C 단독 요소 개수: 2
# 세 집합의 교집합 개수: 1

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# **벤 다이어그램을 그리면서, 특정 조건을 만족하는 경우 색상을 다르게 지정하는 코드**를 작성하세요.
#
# - **조건:** 두 개의 집합을 비교할 때, **교집합이 2개 이상이면 노란색, 그렇지 않으면 기본 색상**을 사용하세요.
#
# ```python
# # 두 개의 집합 정의
# set_A = {"사과", "바나나", "체리", "망고"}
# set_B = {"바나나", "망고", "포도", "수박"}
# ```
#
# </aside>

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# 두 개의 집합 정의
set_A = {"사과", "바나나", "체리", "망고"}
set_B = {"바나나", "망고", "포도", "수박"}

intersection = set_A & set_B

v = venn2([set_A, set_B], set_labels=('Set A', 'Set B'))

if len(intersection) >= 2:
    if v.get_patch_by_id('11'):
        v.get_patch_by_id('11').set_color('yellow')
        v.get_patch_by_id('11').set_alpha(1.0)

plt.show()

# %% [markdown]
# ## 범주형 데이터 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# **샘플 데이터를 직접 생성한 후 Seaborn을 활용하여 막대 그래프(bar plot)를 생성하는 코드**를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# data = pd.DataFrame({
#     "카테고리": ["X", "X", "Y", "Y", "Z", "Z", "Z", "X", "Y", "Z"],
#     "값": [5, 9, 4, 6, 12, 10, 14, 7, 5, 18]
# })
# ```
#
# </aside>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 샘플 데이터 생성
data = pd.DataFrame({
    "카테고리": ["X", "X", "Y", "Y", "Z", "Z", "Z", "X", "Y", "Z"],
    "값": [5, 9, 4, 6, 12, 10, 14, 7, 5, 18]
})

plt.rcParams['font.family'] = 'AppleGothic'  #한글 깨짐 방지

# Seaborn 막대 그래프 생성
sns.barplot(data=data, x="카테고리", y="값")
plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **Seaborn의 `sns.boxplot()`을 활용하여 범주형 데이터의 분포를 시각화하는 코드**를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# data = pd.DataFrame({
#     "group": ["A", "A", "B", "B", "C", "C", "C", "A", "B", "C"],
#     "score": [65, 70, 55, 60, 90, 85, 95, 72, 58, 88]
# })
# ```
#
# </aside>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 샘플 데이터 생성
data = pd.DataFrame({
    "group": ["A", "A", "B", "B", "C", "C", "C", "A", "B", "C"],
    "score": [65, 70, 55, 60, 90, 85, 95, 72, 58, 88]
})

sns.boxplot(data=data, x="group", y="score")
plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# **Seaborn의 `sns.violinplot()`과 `sns.stripplot()`을 함께 사용하여 범주형 데이터의 분포를 더욱 자세히 시각화하는 코드**를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# data = pd.DataFrame({
#     "category": ["A", "A", "B", "B", "C", "C", "C", "A", "B", "C"],
#     "score": [80, 85, 70, 75, 95, 90, 100, 82, 72, 98]
# })
# ```
#
# </aside>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 샘플 데이터 생성
data = pd.DataFrame({
    "category": ["A", "A", "B", "B", "C", "C", "C", "A", "B", "C"],
    "score": [80, 85, 70, 75, 95, 90, 100, 82, 72, 98]
})

sns.violinplot(data=data, x="category", y="score", color="lightgray")

sns.stripplot(data=data, x="category", y="score", color="red", jitter=True)

plt.show()

# %% [markdown]
# ## 연속형 데이터 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# 평균 0, 표준편차 1을 따르는 정규 분포 데이터를 500개 생성한 후, **히스토그램과 KDE를 함께 시각화하는 코드**를 작성하세요.
#
# ```python
# # 정규 분포를 따르는 데이터 생성
# np.random.seed(42)
# data = np.random.randn(500)
# ```
#
# </aside>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 정규 분포를 따르는 데이터 생성
np.random.seed(42)
data = np.random.randn(500)

plt.rcParams['axes.unicode_minus'] = False

sns.histplot(data, kde=True)
plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 0부터 20까지 균등한 간격으로 생성된 데이터를 사용하여, **사인 함수의 선 그래프를 그리는 코드**를 작성하세요.
#
# ```python
# # X 값 생성 (0부터 20까지 100개의 균등한 값)
# x = np.linspace(0, 20, 100)
# y = np.sin(x)
# ```
#
# </aside>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# X 값 생성 (0부터 20까지 100개의 균등한 값)
x = np.linspace(0, 20, 100)
y = np.sin(x)

plt.rcParams['axes.unicode_minus'] = False

# 선 그래프 생성
sns.lineplot(x=x, y=y)
plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 랜덤한 **100개의 연속형 데이터**를 생성하여, **산점도와 회귀선을 포함한 그래프를 그리는 코드**를 작성하세요.
#
# ```python
# # 난수 생성 (재현 가능성 유지)
# np.random.seed(0)
# x = np.random.rand(100) * 10  # 0~10 사이 난수
# y = 2 * x + np.random.randn(100)  # x와 비례하는 관계, 약간의 변동 추가
# ```
#
# </aside>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 난수 생성 (재현 가능성 유지)
np.random.seed(0)
x = np.random.rand(100) * 10  # 0~10 사이 난수
y = 2 * x + np.random.randn(100)  # x와 비례하는 관계, 약간의 변동 추가

sns.regplot(x=x, y=y)

plt.show()

# %% [markdown]
# ## 관계 데이터 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# Seaborn의 `scatterplot`을 활용하여 "총 결제 금액"(`total_bill`)과 "팁"(`tip`)의 관계를 시각화하는 코드를 작성하세요.
#
# 단, `scatterplot`의 색상과 스타일을 다르게 설정하여 출력해야 합니다.
#
# ```python
# # 예제 데이터 로드 (Seaborn 내장 데이터셋: tips)
# tips = sns.load_dataset("tips")
# ```
#
# </aside>

# %%
import ssl
import seaborn as sns
import matplotlib.pyplot as plt

# SSL 인증서 검증 비활성화 설정 (데이터 로드 에러 우회)
ssl._create_default_https_context = ssl._create_unverified_context

# 예제 데이터 로드 (Seaborn 내장 데이터셋: tips)
tips = sns.load_dataset("tips")

plt.rcParams['axes.unicode_minus'] = False
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day", style="smoker")
plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# `sns.regplot`을 사용하여 "총 결제 금액"(`total_bill`)과 "팁"(`tip`)의 관계를 나타내는 회귀선 그래프를 그리고, 산점도의 투명도를 조정하는 코드를 작성하세요.
#
# **단, 산점도에서 특정 성별(`sex`)만 필터링하여 표시해야 합니다.**
#
# ```python
# # 예제 데이터 로드
# tips = sns.load_dataset("tips")
# ```
#
# </aside>

# %%
import ssl
import seaborn as sns
import matplotlib.pyplot as plt

ssl._create_default_https_context = ssl._create_unverified_context

# 예제 데이터 로드
tips = sns.load_dataset("tips")

#Male로 필터링
male_tips = tips[tips["sex"] == "Male"]

sns.regplot(
    data=male_tips, 
    x="total_bill", 
    y="tip", 
    scatter_kws={'alpha': 0.3}
)

plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# `sns.pairplot`을 사용하여 다중 변수(`total_bill`, `tip`, `size`) 간의 관계를 성별(`sex`)과 요일(`day`)에 따라 시각화하는 코드를 작성하세요.
#
# 단, 요일(`day`)에 따라 다른 색상을 적용해야 합니다.
#
# ```python
# # 예제 데이터 로드
# tips = sns.load_dataset("tips")
# ```
#
# </aside>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 예제 데이터 로드
tips = sns.load_dataset("tips")

sns.pairplot(data=tips, vars=["total_bill", "tip", "size"], hue="day")

plt.show()

# %% [markdown]
# ## 시계열 데이터 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# **100일간의 시계열 데이터를 생성하고, 이를 선 그래프로 시각화하는 코드**를 작성하세요.
#
# ```python
# # 시계열 데이터 생성
# np.random.seed(42)
# date_range = pd.date_range(start="2023-01-01", periods=100, freq="D")  # 100일간의 날짜 생성
# values = np.cumsum(np.random.randn(100))  # 랜덤 값의 누적합
# ```
#
# </aside>

# %%
import ssl
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 시계열 데이터 생성
np.random.seed(42)
date_range = pd.date_range(start="2023-01-01", periods=100, freq="D")  # 100일간의 날짜 생성
values = np.cumsum(np.random.randn(100))  # 랜덤 값의 누적합

# 데이터프레임 구축
df = pd.DataFrame({
    "Date": date_range,
    "Value": values
})

# 시계열 선 그래프 생성
sns.lineplot(data=df, x="Date", y="Value")

# X축 날짜 라벨이 겹치지 않도록 회전 설정
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **1번 퀘스트에서 생성한 데이터를 기반으로 7일 이동 평균을 계산하고, 원본 데이터와 함께 그래프로 비교**하는 코드를 작성하세요.
#
# ```python
# # 시계열 데이터 생성
# np.random.seed(42)
# date_range = pd.date_range(start="2023-01-01", periods=100, freq="D")
# values = np.cumsum(np.random.randn(100))
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 시계열 데이터 생성
np.random.seed(42)
date_range = pd.date_range(start="2023-01-01", periods=100, freq="D")
values = np.cumsum(np.random.randn(100))

# 데이터프레임 생성 및 DatetimeIndex 설정
df = pd.DataFrame({"Value": values}, index=date_range)

df["7D_MA"] = df["Value"].rolling(window=7).mean()

# 2. 그래프 시각화
plt.figure(figsize=(10, 6))

sns.lineplot(data=df, x=df.index, y="Value", label="Original", alpha=0.5)
sns.lineplot(data=df, x=df.index, y="7D_MA", label="7-Day Moving Average", linewidth=2)

plt.title("Original vs 7-Day Moving Average")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# **1번 퀘스트에서 생성한 시계열 데이터에서 이상치를 탐지하고, 이상치만 강조하여 그래프에 표시하는 코드**를 작성하세요.
#
# 이상치는 사분위수 범위(IQR)를 이용해 판단합니다.
#
# ```python
# # 시계열 데이터 생성
# np.random.seed(42)
# date_range = pd.date_range(start="2023-01-01", periods=100, freq="D")
# values = np.cumsum(np.random.randn(100))
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 시계열 데이터 생성
np.random.seed(42)
date_range = pd.date_range(start="2023-01-01", periods=100, freq="D")
values = np.cumsum(np.random.randn(100))

# 데이터프레임 생성
df = pd.DataFrame({"Value": values}, index=date_range)

Q1 = df["Value"].quantile(0.25)
Q3 = df["Value"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["Value"] < lower_bound) | (df["Value"] > upper_bound)]

plt.figure(figsize=(10, 6))

sns.lineplot(data=df, x=df.index, y="Value", label="Trend", alpha=0.6)

if not outliers.empty:
    sns.scatterplot(data=outliers, x=outliers.index, y="Value", color="red", s=100, marker="X", label="Outlier")

plt.title("Time Series Outlier Detection (IQR)")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 리샘플링 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# `pandas`를 사용하여 **3시간 간격의 시계열 데이터를 생성한 후**, 하루 단위(`D`)로 **평균을 구하는 다운샘플링을 수행하는 코드**를 작성하세요.
#
# ```python
# # 3시간 간격의 시계열 데이터 생성 (2024년 1월 1일부터 5일까지)
# date_rng = pd.date_range(start="2024-01-01", end="2024-01-05", freq="3h")
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

# 3시간 간격의 시계열 데이터 생성 (2024년 1월 1일부터 5일까지)
date_rng = pd.date_range(start="2024-01-01", end="2024-01-05", freq="3h")

np.random.seed(42)
df = pd.DataFrame(data={"Metrics": np.random.randint(10, 100, size=len(date_rng))}, index=date_rng)

df_daily = df.resample(rule="D").mean()

print("--- 원본 데이터 (상위 5개 행) ---")
print(df.head())
print("\n--- 일별 다운샘플링 결과 ---")
print(df_daily)
# Out:
# --- 원본 데이터 (상위 5개 행) ---
#                      Metrics
# 2024-01-01 00:00:00       61
# 2024-01-01 03:00:00       24
# 2024-01-01 06:00:00       81
# 2024-01-01 09:00:00       70
# 2024-01-01 12:00:00       30
#
# --- 일별 다운샘플링 결과 ---
#             Metrics
# 2024-01-01   67.250
# 2024-01-02   53.375
# 2024-01-03   49.500
# 2024-01-04   66.375
# 2024-01-05   24.000

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 3시간 간격으로 생성된 시계열 데이터에서 **1시간 단위로 업샘플링한 후, 선형 보간(`linear`)을 적용하는 코드**를 작성하세요.
#
# ```python
# # 3시간 간격의 시계열 데이터 생성
# date_rng = pd.date_range(start="2024-01-01", end="2024-01-03", freq="3h")
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

# 3시간 간격의 시계열 데이터 생성
date_rng = pd.date_range(start="2024-01-01", end="2024-01-03", freq="3h")

np.random.seed(42)
df = pd.DataFrame(data={"Metrics": np.random.randint(10, 50, size=len(date_rng))}, index=date_rng)

df_upsampled = df.resample(rule="1h").asfreq()

df_interpolated = df_upsampled.interpolate(method="linear")

print("--- 원본 데이터 (일부) ---")
print(df.head(3))
print("\n--- 1시간 단위 업샘플링 및 선형 보간 결과 (일부) ---")
print(df_interpolated.head(7))
# Out:
# --- 원본 데이터 (일부) ---
#                      Metrics
# 2024-01-01 00:00:00       48
# 2024-01-01 03:00:00       38
# 2024-01-01 06:00:00       24
#
# --- 1시간 단위 업샘플링 및 선형 보간 결과 (일부) ---
#                        Metrics
# 2024-01-01 00:00:00  48.000000
# 2024-01-01 01:00:00  44.666667
# 2024-01-01 02:00:00  41.333333
# 2024-01-01 03:00:00  38.000000
# 2024-01-01 04:00:00  33.333333
# 2024-01-01 05:00:00  28.666667
# 2024-01-01 06:00:00  24.000000

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 3시간 간격으로 생성된 시계열 데이터에서 하루 단위(`D`)로 다운샘플링을 수행한 후, 각 날짜에 해당하는 최소(`min`) 값과 최대(`max`) 값을 출력하는 코드를 작성하세요.
#
# ```python
# # 3시간 간격의 시계열 데이터 생성
# date_rng = pd.date_range(start="2024-01-01", end="2024-01-07", freq="3h")
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

# 3시간 간격의 시계열 데이터 생성
date_rng = pd.date_range(start="2024-01-01", end="2024-01-07", freq="3h")

np.random.seed(42)
df = pd.DataFrame(data={"Metrics": np.random.randint(5, 150, size=len(date_rng))}, index=date_rng)

df_daily_extremes = df.resample(rule="D").agg(["min", "max"])

print("--- 일별 최솟값 및 최댓값 집계 결과 ---")
print(df_daily_extremes)
# Out:
# --- 일별 최솟값 및 최댓값 집계 결과 ---
#            Metrics
#                min  max
# 2024-01-01      19  126
# 2024-01-02       6  135
# 2024-01-03      25  134
# 2024-01-04      19  135
# 2024-01-05      18  139
# 2024-01-06      12  134
# 2024-01-07      39   39

# %% [markdown]
# ## 이동평균 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# 주어진 시계열 데이터에서 **7일 단순 이동평균(SMA)** 을 계산하여 새로운 컬럼을 추가하는 코드를 작성하세요.
#
# ```python
# # 샘플 시계열 데이터 생성
# date_rng = pd.date_range(start="2024-01-01", end="2024-01-20", freq="D")
# df = pd.DataFrame({
#     "datetime": date_rng,
#     "value": np.random.randint(50, 150, size=len(date_rng))
# })
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
date_rng = pd.date_range(start="2024-01-01", end="2024-01-20", freq="D")
df = pd.DataFrame({
    "datetime": date_rng,
    "value": np.random.randint(50, 150, size=len(date_rng))
})

df["SMA_7"] = df["value"].rolling(window=7).mean()

print(df)
# Out:
#      datetime  value       SMA_7
# 0  2024-01-01    101         NaN
# 1  2024-01-02    142         NaN
# 2  2024-01-03     64         NaN
# 3  2024-01-04    121         NaN
# 4  2024-01-05    110         NaN
# 5  2024-01-06     70         NaN
# 6  2024-01-07    132  105.714286
# 7  2024-01-08    136  110.714286
# 8  2024-01-09    124  108.142857
# 9  2024-01-10    124  116.714286
# 10 2024-01-11    137  119.000000
# 11 2024-01-12    149  124.571429
# 12 2024-01-13     73  125.000000
# 13 2024-01-14     52  113.571429
# 14 2024-01-15     71  104.285714
# 15 2024-01-16    102  101.142857
# 16 2024-01-17     51   90.714286
# 17 2024-01-18    137   90.714286
# 18 2024-01-19     79   80.714286
# 19 2024-01-20     87   82.714286

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 시계열 데이터에서 **7일 지수 이동평균(EMA)** 을 계산하고, 기존 데이터와 비교하여 출력하는 코드를 작성하세요.
#
# ```python
# # 샘플 시계열 데이터 생성
# date_rng = pd.date_range(start="2024-01-01", end="2024-01-20", freq="D")
# df = pd.DataFrame({
#     "datetime": date_rng,
#     "value": np.random.randint(50, 150, size=len(date_rng))
# })
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
date_rng = pd.date_range(start="2024-01-01", end="2024-01-20", freq="D")
df = pd.DataFrame({
    "datetime": date_rng,
    "value": np.random.randint(50, 150, size=len(date_rng))
})

df["EMA_7"] = df["value"].ewm(span=7, adjust=False).mean()

print(df[["datetime", "value", "EMA_7"]])
# Out:
#      datetime  value       EMA_7
# 0  2024-01-01    101  101.000000
# 1  2024-01-02    142  111.250000
# 2  2024-01-03     64   99.437500
# 3  2024-01-04    121  104.828125
# 4  2024-01-05    110  106.121094
# 5  2024-01-06     70   97.090820
# 6  2024-01-07    132  105.818115
# 7  2024-01-08    136  113.363586
# 8  2024-01-09    124  116.022690
# 9  2024-01-10    124  118.017017
# 10 2024-01-11    137  122.762763
# 11 2024-01-12    149  129.322072
# 12 2024-01-13     73  115.241554
# 13 2024-01-14     52   99.431166
# 14 2024-01-15     71   92.323374
# 15 2024-01-16    102   94.742531
# 16 2024-01-17     51   83.806898
# 17 2024-01-18    137   97.105174
# 18 2024-01-19     79   92.578880
# 19 2024-01-20     87   91.184160

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 주어진 시계열 데이터에서 **이동평균을 활용하여 변동성이 큰 날을 탐색하는 코드**를 작성하세요.
#
# **7일 단순 이동평균(SMA)과 비교하여 특정 일자의 값이 이동평균보다 ±20% 이상 차이가 나는 경우만 출력**하세요.
#
# ```python
# # 샘플 시계열 데이터 생성
# date_rng = pd.date_range(start="2024-01-01", end="2024-01-20", freq="D")
# df = pd.DataFrame({
#     "datetime": date_rng,
#     "value": np.random.randint(50, 150, size=len(date_rng))
# })
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
date_rng = pd.date_range(start="2024-01-01", end="2024-01-20", freq="D")
df = pd.DataFrame({
    "datetime": date_rng,
    "value": np.random.randint(50, 150, size=len(date_rng))
})

df["SMA_7"] = df["value"].rolling(window=7).mean()

df_valid = df.dropna(subset=["SMA_7"])

high_volatility = df_valid[abs(df_valid["value"] - df_valid["SMA_7"]) / df_valid["SMA_7"] >= 0.2]

print("--- 변동성이 큰 날 (SMA 대비 ±20% 이상) ---")
print(high_volatility[["datetime", "value", "SMA_7"]])
# Out:
# --- 변동성이 큰 날 (SMA 대비 ±20% 이상) ---
#      datetime  value       SMA_7
# 6  2024-01-07    132  105.714286
# 7  2024-01-08    136  110.714286
# 12 2024-01-13     73  125.000000
# 13 2024-01-14     52  113.571429
# 14 2024-01-15     71  104.285714
# 16 2024-01-17     51   90.714286
# 17 2024-01-18    137   90.714286

# %% [markdown]
# ## 금융 데이터 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# **샘플 금융 데이터프레임을 직접 생성한 후**, 데이터의 **기본 정보(행 개수, 열 개수, 데이터 타입 등)를 출력하는 코드**를 작성하세요.
#
# ```python
# # 샘플 금융 데이터 생성
# data = {
#     'Date': pd.date_range(start='2024-01-01', periods=10, freq='D'),
#     'Open': [100, 102, 105, 103, 108, 107, 110, 112, 115, 118],
#     'High': [102, 106, 108, 107, 110, 109, 112, 115, 117, 120],
#     'Low': [98, 100, 103, 101, 106, 105, 108, 110, 113, 116],
#     'Close': [101, 104, 106, 105, 109, 108, 111, 113, 116, 119],
#     'Volume': [1000, 1200, 1500, 1300, 1600, 1400, 1700, 1800, 1900, 2000]
# }
# ```
#
# </aside>

# %%
import pandas as pd

data = {
    'Date': pd.date_range(start='2024-01-01', periods=10, freq='D'),
    'Open': [100, 102, 105, 103, 108, 107, 110, 112, 115, 118],
    'High': [102, 106, 108, 107, 110, 109, 112, 115, 117, 120],
    'Low': [98, 100, 103, 101, 106, 105, 108, 110, 113, 116],
    'Close': [101, 104, 106, 105, 109, 108, 111, 113, 116, 119],
    'Volume': [1000, 1200, 1500, 1300, 1600, 1400, 1700, 1800, 1900, 2000]
}

df = pd.DataFrame(data)

print(f"행 개수: {df.shape[0]}, 열 개수: {df.shape[1]}")
print()
print(df.info())
print()
print(df.head())
# Out:
# 행 개수: 10, 열 개수: 6
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    10 non-null     datetime64[ns]
#  1   Open    10 non-null     int64
#  2   High    10 non-null     int64
#  3   Low     10 non-null     int64
#  4   Close   10 non-null     int64
#  5   Volume  10 non-null     int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 612.0 bytes
# None
#
#         Date  Open  High  Low  Close  Volume
# 0 2024-01-01   100   102   98    101    1000
# 1 2024-01-02   102   106  100    104    1200
# 2 2024-01-03   105   108  103    106    1500
# 3 2024-01-04   103   107  101    105    1300
# 4 2024-01-05   108   110  106    109    1600

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 주어진 `df` 데이터프레임에서 **5일 이동평균(SMA)과 5일 지수 이동평균(EMA)을 계산하는 코드**를 작성하세요.
#
# ```python
# # 샘플 금융 데이터 생성
# data = {
#     'Date': pd.date_range(start='2024-01-01', periods=10, freq='D'),
#     'Close': [101, 104, 106, 105, 109, 108, 111, 113, 116, 119]
# }
# ```
#
# </aside>

# %%
import pandas as pd

data = {
    'Date': pd.date_range(start='2024-01-01', periods=10, freq='D'),
    'Close': [101, 104, 106, 105, 109, 108, 111, 113, 116, 119]
}

df = pd.DataFrame(data)

df["SMA_5"] = df["Close"].rolling(window=5).mean()
df["EMA_5"] = df["Close"].ewm(span=5, adjust=False).mean()

print(df[["Date", "Close", "SMA_5", "EMA_5"]])
# Out:
#         Date  Close  SMA_5       EMA_5
# 0 2024-01-01    101    NaN  101.000000
# 1 2024-01-02    104    NaN  102.000000
# 2 2024-01-03    106    NaN  103.333333
# 3 2024-01-04    105    NaN  103.888889
# 4 2024-01-05    109  105.0  105.592593
# 5 2024-01-06    108  106.4  106.395062
# 6 2024-01-07    111  107.8  107.930041
# 7 2024-01-08    113  109.2  109.620027
# 8 2024-01-09    116  111.4  111.746685
# 9 2024-01-10    119  113.4  114.164457

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# `df` 데이터프레임에서 **주간(7일) 단위로 종가(Close) 평균을 리샘플링한 후**, 이를 바탕으로 **주간 변동성(표준편차)을 계산하는 코드**를 작성하세요.
#
# ```python
# # 샘플 금융 데이터 생성 (30일치)
# date_rng = pd.date_range(start='2024-01-01', periods=30, freq='D')
# close_prices = np.random.uniform(100, 200, size=len(date_rng))  # 100~200 사이의 랜덤 종가 생성
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
date_rng = pd.date_range(start='2024-01-01', periods=30, freq='D')
close_prices = np.random.uniform(100, 200, size=len(date_rng))

df = pd.DataFrame({"Close": close_prices}, index=date_rng)

weekly_mean = df["Close"].resample("W").mean()
weekly_std = df["Close"].resample("W").std()

result = pd.DataFrame({"주간_평균": weekly_mean, "주간_변동성(표준편차)": weekly_std})

print("--- 주간 종가 평균 및 변동성 ---")
print(result)
# Out:
# --- 주간 종가 평균 및 변동성 ---
#                  주간_평균  주간_변동성(표준편차)
# 2024-01-07  143.228623     33.721784
# 2024-01-14  160.151998     35.575756
# 2024-01-21  136.132217     16.658785
# 2024-01-28  139.330779     21.794446
# 2024-02-04  131.943249     38.605496

# %% [markdown]
# ## 정규 분포 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# 평균 `60`, 표준 편차 `15`를 갖는 정규 분포에서 500개의 데이터를 생성한 후, 데이터의 **기본 통계 정보(평균, 표준 편차, 최소값, 최대값)를 출력하는 코드**를 작성하세요.
#
# ```python
# # 평균 60, 표준 편차 15인 정규 분포에서 500개의 난수 생성
# data = np.random.normal(loc=60, scale=15, size=500)
# ```
#
# </aside>

# %%
import numpy as np

np.random.seed(42)
data = np.random.normal(loc=60, scale=15, size=500)

print(f"평균: {data.mean():.4f}")
print(f"표준 편차: {data.std():.4f}")
print(f"최소값: {data.min():.4f}")
print(f"최대값: {data.max():.4f}")
# Out:
# 평균: 60.1026
# 표준 편차: 14.7041
# 최소값: 11.3810
# 최대값: 117.7910

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 평균 `50`, 표준 편차 `10`을 갖는 정규 분포에서 특정 값 `x=65`의 **확률 밀도 함수(PDF) 값을 계산하고 출력하는 코드**를 작성하세요.
#
# </aside>

# %%
from scipy.stats import norm

mu, sigma = 50, 10
x = 65

pdf_value = norm.pdf(x, loc=mu, scale=sigma)

print(f"x={x}에서의 PDF 값: {pdf_value:.6f}")
# Out:
# x=65에서의 PDF 값: 0.012952

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 평균 `70`, 표준 편차 `8`을 갖는 정규 분포에서 **(1) 특정 값 `x=80` 이하일 확률을 CDF로 계산하고, (2) 상위 5%에 해당하는 점수를 PPF로 계산하여 출력하는 코드**를 작성하세요.
#
# </aside>

# %%
from scipy.stats import norm

mu, sigma = 70, 8

x = 80
cdf_value = norm.cdf(x, loc=mu, scale=sigma)
print(f"x={x} 이하일 확률 (CDF): {cdf_value:.2f}")

top5_score = norm.ppf(0.95, loc=mu, scale=sigma)
print(f"상위 5%에 해당하는 점수 (PPF): {top5_score:.2f}")
# Out:
# x=80 이하일 확률 (CDF): 0.89
# 상위 5%에 해당하는 점수 (PPF): 83.16

# %% [markdown]
# ## 기술 통계 - 미니퀘스트&과제

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# **주어진 데이터에서 평균과 중앙값의 차이를 계산하는 코드**를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# np.random.seed(42)
# data = np.random.normal(loc=50, scale=10, size=100)  # 평균 50, 표준편차 10인 정규 분포 데이터 생성
# df = pd.DataFrame(data, columns=["value"])  # 데이터프레임 생성
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=100)
df = pd.DataFrame(data, columns=["value"])

mean_val = df["value"].mean()
median_val = df["value"].median()
diff = abs(mean_val - median_val)

print(f"평균: {mean_val:.2f}")
print(f"중앙값: {median_val:.2f}")
print(f"평균과 중앙값의 차이: {diff:.2f}")
# Out:
# 평균: 48.96
# 중앙값: 48.73
# 평균과 중앙값의 차이: 0.23

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **데이터에서 이상값(Outlier)을 찾아 제거한 후, 원래 데이터와 이상값 제거 후 데이터의 평균을 비교하는 코드**를 작성하세요.
#
# 이상값은 **IQR(사분위 범위)를 사용하여 탐지**하세요.
#
# ```python
# # 샘플 데이터 생성
# np.random.seed(42)
# data = np.random.normal(loc=50, scale=10, size=100)  # 평균 50, 표준편차 10인 정규 분포 데이터 생성
# df = pd.DataFrame(data, columns=["value"])  # 데이터프레임 생성
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=100)
df = pd.DataFrame(data, columns=["value"])

Q1 = df["value"].quantile(0.25)
Q3 = df["value"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df_clean = df[(df["value"] >= lower) & (df["value"] <= upper)]

print(f"원래 데이터 평균: {df['value'].mean():.4f}  (n={len(df)})")
print(f"이상값 제거 후 평균: {df_clean['value'].mean():.4f}  (n={len(df_clean)})")
# Out:
# 원래 데이터 평균: 48.9615  (n=100)
# 이상값 제거 후 평균: 49.2157  (n=99)

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# **데이터의 왜도(Skewness)와 첨도(Kurtosis)를 계산하여 데이터의 분포 특성을 분석하는 코드**를 작성하세요.
#
# ```python
# # 샘플 데이터 생성
# np.random.seed(42)
# data = np.random.normal(loc=50, scale=10, size=100)  # 평균 50, 표준편차 10인 정규 분포 데이터 생성
# df = pd.DataFrame(data, columns=["value"])  # 데이터프레임 생성
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd

# 샘플 데이터 생성
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=100)  # 평균 50, 표준편차 10인 정규 분포 데이터 생성
df = pd.DataFrame(data, columns=["value"])  # 데이터프레임 생성

# 왜도와 첨도 계산
skewness = df["value"].skew()
kurtosis = df["value"].kurt()

print(f"계산된 왜도(Skewness): {skewness:.4f}")
print(f"계산된 첨도(Kurtosis): {kurtosis:.4f}")
# Out:
# 계산된 왜도(Skewness): -0.1779
# 계산된 첨도(Kurtosis): -0.1010

# %% [markdown]
# ## 가설 검정 - 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# **단일 표본 t-검정(One-Sample t-test)** 을 수행하여 샘플 데이터의 평균이 특정 값과 유의미한 차이가 있는지 검정하는 코드를 작성하세요.
#
# (평균 `50`, 표준 편차 `5`를 따르는 정규 분포에서 30개의 데이터를 생성하고, 해당 데이터가 평균 `52`와 차이가 있는지 확인하세요.)
#
# ```python
# # 샘플 데이터 생성
# np.random.seed(42)
# sample_data = np.random.normal(loc=50, scale=5, size=30)  # 평균 50, 표준편차 5인 데이터 30개 생성
# ```
#
# </aside>

# %%
import numpy as np
from scipy import stats

# 샘플 데이터 생성
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=5, size=30)  # 평균 50, 표준편차 5인 데이터 30개 생성

# 검정하고자 하는 모평균 대립 기준값
popmean = 52

t_statistic, p_value = stats.ttest_1samp(sample_data, popmean)

print(f"t-통계량 (t-statistic): {t_statistic:.4f}")
print(f"p-값 (p-value): {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print(f"결론: p-값이 유의수준 {alpha}보다 작으므로 귀무가설이 아니다.")
    print(f"      (표본 평균은 {popmean}와 통계적으로 유의미한 차이가 있다.)")
else:
    print(f"결론: p-값이 유의수준 {alpha}보다 크거나 같으므로 귀무가설이다.")
    print(f"      (표본 평균은 {popmean}와 통계적으로 유의미한 차이가 없다고 볼 수 있다.)")
# Out:
# t-통계량 (t-statistic): -3.5793
# p-값 (p-value): 0.0012
# 결론: p-값이 유의수준 0.05보다 작으므로 귀무가설이 아니다.
#       (표본 평균은 52와 통계적으로 유의미한 차이가 있다.)

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# **카이제곱 검정(Chi-Square Test)** 을 수행하여 관측된 데이터와 기대값이 유의미한 차이가 있는지 확인하는 코드를 작성하세요.
#
# ```python
# # 관측된 데이터 (Observed)
# observed = np.array([50, 60, 90])
#
# # 기대값 (Expected)
# expected = np.array([66, 66, 66]) * (observed.sum() / np.sum([66, 66, 66]))
# ```
#
# </aside>

# %%
import numpy as np
from scipy import stats

# 관측된 데이터 (Observed)
observed = np.array([50, 60, 90])

# 기대값 (Expected)
expected = np.array([66, 66, 66]) * (observed.sum() / np.sum([66, 66, 66]))

chi_statistic, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

print(f"카이제곱 통계량 (Chi-Square Statistic): {chi_statistic:.4f}")
print(f"p-값 (p-value): {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print(f"결론: p-값이 유의수준 {alpha}보다 작으므로 귀무가설이 아니다.")
else:
    print(f"결론: p-값이 유의수준 {alpha}보다 크거나 같으므로 귀무가설이다.")
# Out:
# 카이제곱 통계량 (Chi-Square Statistic): 13.0000
# p-값 (p-value): 0.0015
# 결론: p-값이 유의수준 0.05보다 작으므로 귀무가설이 아니다.

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# **분산 분석(ANOVA, Analysis of Variance)** 을 수행하여 여러 그룹의 평균이 서로 다른지 검정하는 코드를 작성하세요.
#
# </aside>
#
# ```python
# # 샘플 데이터 생성
# np.random.seed(42)
# group_1 = np.random.normal(loc=50, scale=10, size=30)  # 평균 50, 표준편차 10
# group_2 = np.random.normal(loc=55, scale=10, size=30)  # 평균 55, 표준편차 10
# group_3 = np.random.normal(loc=60, scale=10, size=30)  # 평균 60, 표준편차 10
# ```

# %%
import numpy as np
from scipy import stats

# 샘플 데이터 생성
np.random.seed(42)
group_1 = np.random.normal(loc=50, scale=10, size=30)  # 평균 50, 표준편차 10
group_2 = np.random.normal(loc=55, scale=10, size=30)  # 평균 55, 표준편차 10
group_3 = np.random.normal(loc=60, scale=10, size=30)  # 평균 60, 표준편차 10

f_statistic, p_value = stats.f_oneway(group_1, group_2, group_3)

print(f"F-통계량 (F-statistic): {f_statistic:.4f}")
print(f"p-값 (p-value): {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print(f"결론: p-값이 유의수준 {alpha}보다 작으므로 귀무가설이 아니다.")
else:
    print(f"결론: p-값이 유의수준 {alpha}보다 크거나 같으므로 귀무가설이다.")
# Out:
# F-통계량 (F-statistic): 12.2095
# p-값 (p-value): 0.0000
# 결론: p-값이 유의수준 0.05보다 작으므로 귀무가설이 아니다.

# %% [markdown]
# ## 통계적 시각화 - 미니퀘스트&과제

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉
#
# NumPy를 사용하여 **평균 70, 표준편차 20을 따르는 정규 분포 데이터 1000개를 생성**한 후, Matplotlib을 활용하여 **박스플롯을 그리는 코드**를 작성하세요.
#
# ```python
# # 데이터 생성 (평균=70, 표준편차=20인 정규 분포 데이터 1000개)
# np.random.seed(42)
# data = np.random.normal(loc=70, scale=20, size=1000)
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성 (평균=70, 표준편차=20인 정규 분포 데이터 1000개)
np.random.seed(42)
data = np.random.normal(loc=70, scale=20, size=1000)

plt.figure(figsize=(6, 8))
plt.boxplot(data, tick_labels=["Data Distribution"])

plt.title("Box Plot of Normal Distribution Data")
plt.show()

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉
#
# 평균이 각각 55와 60이고, 표준편차가 8인 두 개의 그룹(A, B) 데이터를 생성한 후, **두 그룹의 데이터 분포를 Seaborn을 활용하여 KDE(커널 밀도 함수)와 함께 히스토그램으로 시각화**하세요.
#
# 이후, **두 그룹 간 평균 차이가 유의미한지 t-검정을 수행하는 코드**를 작성하세요.
#
# ```python
# # 데이터 생성
# np.random.seed(42)
# group_A = np.random.normal(loc=55, scale=8, size=200)  # 평균 55, 표준편차 8
# group_B = np.random.normal(loc=60, scale=8, size=200)  # 평균 60, 표준편차 8
# ```
#
# </aside>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 데이터 생성
np.random.seed(42)
group_A = np.random.normal(loc=55, scale=8, size=200)
group_B = np.random.normal(loc=60, scale=8, size=200)

# 시각화
fig, ax = plt.subplots(figsize=(9, 5))

sns.histplot(group_A, kde=True, color='steelblue', alpha=0.5, label='Group A (μ=55)', ax=ax)
sns.histplot(group_B, kde=True, color='tomato',    alpha=0.5, label='Group B (μ=60)', ax=ax)

ax.set_title('Group A vs Group B — Distribution with KDE', fontsize=14)
ax.set_xlabel('Value')
ax.set_ylabel('Count')
ax.legend()
plt.tight_layout()
plt.show()

# t검정
t_stat, p_value = stats.ttest_ind(group_A, group_B)

print("=" * 40)
print(f"  t-통계량 : {t_stat:.4f}")
print(f"  p-값     : {p_value:.4f}")
print("=" * 40)

alpha = 0.05
if p_value < alpha:
    print(f"→ p < {alpha}  :  두 그룹 간 평균 차이는 통계적으로 유의미합니다.")
else:
    print(f"→ p ≥ {alpha}  :  두 그룹 간 평균 차이는 통계적으로 유의미하지 않습니다.")
# Out:
# ========================================
#   t-통계량 : -7.8344
#   p-값     : 0.0000
# ========================================
# → p < 0.05  :  두 그룹 간 평균 차이는 통계적으로 유의미합니다.

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉
#
# 광고 A를 본 500명 중 120명이 클릭하였고, 광고 B를 본 500명 중 150명이 클릭을 한 데이터가 있습니다.
#
# 이 데이터를 바탕으로 **카이제곱 검정을 수행하여 광고 A와 B의 클릭률 차이가 유의미한지 분석하고, Seaborn의 barplot을 사용하여 클릭률을 비교하는 그래프를 그리는 코드**를 작성하세요.
#
# ```python
# # 데이터 생성 (광고 A와 B의 클릭 여부)
# observed_data = pd.DataFrame({
#     "Ad_A": [120, 380],  # 광고 A 클릭(120명) vs 미클릭(380명)
#     "Ad_B": [150, 350]   # 광고 B 클릭(150명) vs 미클릭(350명)
# }, index=["Click", "No Click"])
# ```
#
# </aside>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 데이터 생성 (광고 A와 B의 클릭 여부)
observed_data = pd.DataFrame({
    "Ad_A": [120, 380],  # 광고 A 클릭(120명) vs 미클릭(380명)
    "Ad_B": [150, 350]   # 광고 B 클릭(150명) vs 미클릭(350명)
}, index=["Click", "No Click"])

print("[ 분할표 ]")
print(observed_data)

# 카이제곱
chi2, p_value, dof, expected = stats.chi2_contingency(observed_data)

print("\n" + "=" * 40)
print(f"  카이제곱 통계량 : {chi2:.4f}")
print(f"  자유도          : {dof}")
print(f"  p-값            : {p_value:.4f}")
print("=" * 40)

alpha = 0.05
if p_value < alpha:
    print(f"→ p < {alpha}  :  두 광고 클릭률 차이는 통계적으로 유의미합니다.")
else:
    print(f"→ p ≥ {alpha}  :  두 광고 클릭률 차이는 통계적으로 유의미하지 않습니다.")

# 클릭률 계산
click_rates = pd.DataFrame({
    "Ad":         ["Ad A", "Ad B"],
    "Click Rate": [120 / 500 * 100, 150 / 500 * 100]   # 단위: %
})

# 시각화
fig, ax = plt.subplots(figsize=(6, 5))

sns.barplot(data=click_rates, x="Ad", y="Click Rate",
            palette=["steelblue", "tomato"], width=0.5, ax=ax)

# 막대 위 수치 표기
for i, row in click_rates.iterrows():
    ax.text(i, row["Click Rate"] + 0.3, f'{row["Click Rate"]:.1f}%',
            ha='center', va='bottom', fontweight='bold')

ax.set_title('Ad A vs Ad B — Click Rate Comparison', fontsize=13)
ax.set_ylabel('Click Rate (%)')
ax.set_xlabel('')
ax.set_ylim(0, 40)
plt.tight_layout()
plt.show()
# Out:
# [ 분할표 ]
#           Ad_A  Ad_B
# Click      120   150
# No Click   380   350
#
# ========================================
#   카이제곱 통계량 : 4.2669
#   자유도          : 1
#   p-값            : 0.0389
# ========================================
# → p < 0.05  :  두 광고 클릭률 차이는 통계적으로 유의미합니다.
# /var/folders/52/bqgpzt9j7bxb3qp5wx2jchg00000gn/T/ipykernel_43045/1639532599.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=click_rates, x="Ad", y="Click Rate",
